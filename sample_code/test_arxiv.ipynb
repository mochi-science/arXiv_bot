# %% [markdown]
# # arXiv　APIを叩いてみる
# - 参考 https://note.nkmk.me/python-arxiv-api-download-rss/
#     - 記事で扱っているversionが古い
# - 参考 https://pypi.org/project/arxiv/
#     - pypiのサイトにExampleが載っているた

# %%
# 使用するライブラリのインポート
import arxiv
import pandas as pd
import os

# %%
def fetch_papers_from_arxiv(search_query=None, max_results=3, csv_filename = "datas/arxiv_papers.csv"):
    """
    arXiv APIを使用して論文を取得し、CSVファイルに保存する関数

    Parameters:
        search_query (dict{"thema": "query"}): 検索クエリ
            ex) queries = {
                    "LLM": 'cat:cs.CL OR cat:cs.AI AND "large language model"',
                    "Machine Learning": 'cat:cs.LG OR cat:stat.ML AND "machine learning"',
                    "XAI": 'cat:cs.AI OR cat:cs.LG AND "explainable AI"'
                }
        max_results (int): 取得する論文の最大数
        csv_filename (str): 保存するCSVファイル名

    Returns:
        DataFrame: 新しい論文情報を含むDataFrame
    """
    if search_query is None:
        # テーマごとのクエリ
        queries = {
            "LLM": 'cat:cs.CL OR cat:cs.AI AND "large language model"',
            "Machine Learning": 'cat:cs.LG OR cat:stat.ML AND "machine learning"',
            "XAI": 'cat:cs.AI OR cat:cs.LG AND "explainable AI"'
        }
    
    # 新しく取得した論文の情報を格納するリスト
    new_papers_list = []

    # 既存のCSVファイルを読み込む（存在すれば）
    if os.path.exists(csv_filename):
        existing_papers_df = pd.read_csv(csv_filename)
    else:
        # CSVが存在しない場合は空のDataFrameを作成
        existing_papers_df = pd.DataFrame(columns=["Title", "Authors", "Published", "URL", "Abstract", "PDF"])

    # 既存のURL一覧を取得
    existing_urls = existing_papers_df["URL"].tolist()

    # 各クエリで論文を取得し、既存のデータと比較
    for theme, query in queries.items():
        search = arxiv.Search(
            query=query,
            max_results=5,  # 各テーマで取得する最大論文数
            sort_by=arxiv.SortCriterion.SubmittedDate
        )

        for result in search.results():
            # 論文情報を辞書にまとめる
            paper_info = {
                "Title": result.title,
                "Theme": theme,
                "Authors": ', '.join([author.name for author in result.authors]),
                "Published": str(result.published),
                "URL": result.entry_id,
                "Abstract": result.summary,
                "PDF": result.pdf_url
            }

            # 既存の論文リストにないか、または更新されている場合はリストに追加
            if paper_info["URL"] not in existing_urls or paper_info["Published"] != existing_papers_df.loc[existing_papers_df["URL"] == paper_info["URL"], "Published"].values[0]:
                new_papers_list.append(paper_info)

    # 新しい論文があれば処理
    if new_papers_list:
        # 新しい論文のDataFrameを作成
        new_papers_df = pd.DataFrame(new_papers_list)

        # 既存の論文と新しい論文を結合
        updated_papers_df = pd.concat([existing_papers_df, new_papers_df], ignore_index=True)

        # CSVファイルに上書き保存
        updated_papers_df.to_csv(csv_filename, index=False)

        # print(f"{len(new_papers_list)} 件の新しい論文を追加しました。")

    return new_papers_df

# %%
fetch_papers_from_arxiv()
# Out:
# C:\Users\tashi\AppData\Local\Temp\ipykernel_26904\3915547482.py:47: DeprecationWarning: The 'Search.results' method is deprecated, use 'Client.results' instead
#   for result in search.results():
#                                                 Title             Theme  \
# 0   To CoT or not to CoT? Chain-of-thought helps m...               LLM
# 1   Decoding Style: Efficient Fine-Tuning of LLMs ...               LLM
# 2   Takin: A Cohort of Superior Quality Zero-shot ...               LLM
# 3   Qwen2.5-Math Technical Report: Toward Mathemat...               LLM
# 4   Measuring Human and AI Values based on Generat...               LLM
# 5                    Fitting Multilevel Factor Models  Machine Learning
# 6         Cartan moving frames and the data manifolds  Machine Learning
# 7   Symmetry-Based Structured Matrices for Efficie...  Machine Learning
# 8   Recurrent Interpolants for Probabilistic Time ...  Machine Learning
# 9   PieClam: A Universal Graph Autoencoder Based o...  Machine Learning
# 10  Towards Interpretable End-Stage Renal Disease ...               XAI
# 11  MonoKAN: Certified Monotonic Kolmogorov-Arnold...               XAI
# 12  Trustworthy Conceptual Explanations for Neural...               XAI
# 13  Predicting Trust In Autonomous Vehicles: Model...               XAI
# 14  XSub: Explanation-Driven Adversarial Attack ag...               XAI
#
#                                               Authors  \
# 0   Zayne Sprague, Fangcong Yin, Juan Diego Rodrig...
# 1   Najmeh Forouzandehmehr, Nima Farrokhsiar, Rami...
# 2   EverestAI, :, Sijin Chen, Yuan Feng, Laipeng H...
# 3   An Yang, Beichen Zhang, Binyuan Hui, Bofei Gao...
# 4   Haoran Ye, Yuhang Xie, Yuanyi Ren, Hanjun Fang...
# 5     Tetiana Parshakova, Trevor Hastie, Stephen Boyd
# 6   Eliot Tron, Rita Fioresi, Nicolas Couellan, St...
# 7   Ashwin Samudre, Mircea Petrache, Brian D. Nord...
# 8   Yu Chen, Marin Biloš, Sarthak Mittal, Wei Deng...
# 9                           Daniel Zilberg, Ron Levie
# 10              Yubo Li, Saba Al-Sayouri, Rema Padman
# 11  Alejandro Polo-Molina, David Alfaya, Jose Portela
# 12  Som Sagar, Aditya Taparia, Harsh Mankodiya, Pr...
# 13  Robert Kaufman, Emi Lee, Manas Satish Bedmutha...
# 14                   Kiana Vu, Phung Lai, Truc Nguyen
#
#                     Published                                URL  \
# 0   2024-09-18 17:55:00+00:00  http://arxiv.org/abs/2409.12183v1
# 1   2024-09-18 17:15:06+00:00  http://arxiv.org/abs/2409.12150v1
# 2   2024-09-18 17:03:12+00:00  http://arxiv.org/abs/2409.12139v1
# 3   2024-09-18 16:45:37+00:00  http://arxiv.org/abs/2409.12122v1
# 4   2024-09-18 16:26:22+00:00  http://arxiv.org/abs/2409.12106v1
# 5   2024-09-18 15:39:12+00:00  http://arxiv.org/abs/2409.12067v1
# 6   2024-09-18 15:31:29+00:00  http://arxiv.org/abs/2409.12057v1
# 7   2024-09-18 07:52:33+00:00  http://arxiv.org/abs/2409.11772v1
# 8   2024-09-18 03:52:48+00:00  http://arxiv.org/abs/2409.11684v1
# 9   2024-09-18 00:49:42+00:00  http://arxiv.org/abs/2409.11618v1
# 10  2024-09-18 16:03:57+00:00  http://arxiv.org/abs/2409.12087v1
# 11  2024-09-17 11:10:59+00:00  http://arxiv.org/abs/2409.11078v1
# 12  2024-09-16 21:11:12+00:00  http://arxiv.org/abs/2409.10733v1
# 13  2024-09-13 16:52:24+00:00  http://arxiv.org/abs/2409.08980v1
# 14  2024-09-13 15:33:32+00:00  http://arxiv.org/abs/2409.08919v1
#
#                                              Abstract  \
# 0   Chain-of-thought (CoT) via prompting is the de...
# 1   Personalized outfit recommendation remains a c...
# 2   With the advent of the big data and large lang...
# 3   In this report, we present a series of math-sp...
# 4   Human values and their measurement are long-st...
# 5   We examine a special case of the multilevel fa...
# 6   The purpose of this paper is to employ the lan...
# 7   There has been much recent interest in designi...
# 8   Sequential models such as recurrent neural net...
# 9   We propose PieClam (Prior Inclusive Exclusive ...
# 10  This study explores the potential of utilizing...
# 11  Artificial Neural Networks (ANNs) have signifi...
# 12  Black box neural networks are an indispensable...
# 13  Low trust remains a significant barrier to Aut...
# 14  Despite its significant benefits in enhancing ...
#
#                                   PDF
# 0   http://arxiv.org/pdf/2409.12183v1
# 1   http://arxiv.org/pdf/2409.12150v1
# 2   http://arxiv.org/pdf/2409.12139v1
# 3   http://arxiv.org/pdf/2409.12122v1
# 4   http://arxiv.org/pdf/2409.12106v1
# 5   http://arxiv.org/pdf/2409.12067v1
# 6   http://arxiv.org/pdf/2409.12057v1
# 7   http://arxiv.org/pdf/2409.11772v1
# 8   http://arxiv.org/pdf/2409.11684v1
# 9   http://arxiv.org/pdf/2409.11618v1
# 10  http://arxiv.org/pdf/2409.12087v1
# 11  http://arxiv.org/pdf/2409.11078v1
# 12  http://arxiv.org/pdf/2409.10733v1
# 13  http://arxiv.org/pdf/2409.08980v1
# 14  http://arxiv.org/pdf/2409.08919v1
